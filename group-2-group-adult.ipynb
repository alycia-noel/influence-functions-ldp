# %%
import time
import math
import copy
import torch
import pickle
import random
import logging
import warnings
import datetime
import pandas as pd
import numpy as np
import seaborn as sns
from copy import deepcopy
import torch.nn as nn
import torch.optim as opt
import matplotlib.pyplot as plt
from imblearn.under_sampling import RandomUnderSampler
import fairlearn.datasets
from tqdm import tqdm
from sklearn import linear_model
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.model_selection import train_test_split
from torch.autograd import grad
from torch.autograd.functional import vhp
from torch.utils.data import Subset, DataLoader
from sklearn.metrics import mean_absolute_error, log_loss, r2_score, accuracy_score, precision_score, recall_score, precision_recall_fscore_support, classification_report
from scipy.stats import spearmanr

warnings.filterwarnings("ignore")

E = math.e

# %% [markdown]
# ### Utility Functions

# %%
from matplotlib.ticker import FormatStrFormatter
import matplotlib.cm as cm
import scienceplots

# %%
def visualize_result(e_k_actual, e_k_estimated, ep, k_):
    plt.rcParams['figure.dpi'] = 300
    plt.style.use(['science'])
#     plt.rcParams.update({'font.size': 5})
    colors = cm.cool(np.linspace(0, 1, len(e_k_estimated)))
#     e_k_estimated = [-1*ek for ek in e_k_estimated]
    fig, ax = plt.subplots()
    
    ax.yaxis.set_major_formatter(FormatStrFormatter('%.4f'))
    ax.xaxis.set_major_formatter(FormatStrFormatter('%.4f'))
    
    min_x = np.min(e_k_actual)
    max_x = np.max(e_k_actual)
    min_y = np.min(e_k_estimated)
    max_y = np.max(e_k_estimated)
    
# #     plt.rcParams['figure.figsize'] = 15, 15
    z = np.polyfit(e_k_actual,  e_k_estimated, 1)
    p = np.poly1d(z)
    xx = np.linspace(-p(2)/p(1), max(e_k_actual)+.0001)
    yy = np.polyval(p, xx)
    #add trendline to plot
    ax.plot(xx, yy, ls="-", color='k')
    
    for k in range(len(e_k_actual)):
        ax.scatter(e_k_actual[k], e_k_estimated[k], zorder=2, s=15, color=colors[k])

    ax.set_title(f'Actual vs. Estimated loss for k={k_:.2f}%', fontsize=8)
    ax.set_xlabel('Actual loss difference', fontsize=8)
    ax.set_ylabel('Estimated loss difference', fontsize=8)
   
    ax.set_xlim(min_x-.0001, max_x+.0001)
    ax.set_ylim(min_y-.0001, max_y+.0001)
    
#     #label_locations = np.arange(5)  
#     #width = 0.25 
    
#     xlabels = np.linspace(min_x-.0001, max_x+.0001, 6)
#     ylabels = np.linspace(min_y-.0001, max_y+.0001, 6)
    
    text = 'MAE = {:.03}\nP = {:.03}'.format(mean_absolute_error(e_k_actual, e_k_estimated), spearmanr(e_k_actual, e_k_estimated).correlation)
#     ax.text(max_x+.00001,min_y-.00008, text, verticalalignment='bottom', horizontalalignment='right', fontsize=8)
# #     ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
# #     plt.tight_layout()
    plt.xticks(rotation = 45, fontsize=7, visible=True)
    plt.yticks(fontsize=7)
    print(text)
    plt.show()
    # cooler color = smaller epsilon

# %%
def get_data_group(dfTrain, feature_set, label, k):    

#     selected_group = dfTrain.loc[dfTrain['sex'] == 0]

    num_to_sample = int((k/100)*len(dfTrain))

    sampled_group = dfTrain.sample(n=num_to_sample, ignore_index=False)
    not_selected = dfTrain.drop(sampled_group.index)

    selected_group_X = sampled_group[feature_set]
    selected_group_y = sampled_group[label]

    not_selected_group_X = not_selected[feature_set]
    not_selected_group_y = not_selected[label]   
    
    return selected_group_X, selected_group_y, not_selected_group_X, not_selected_group_y

# %%
def get_adult():
    train_url = 'adult.data'
    test_url = 'adult.test'

    dfTrain = pd.read_csv(train_url, header=None, sep=',')
    dfTest = pd.read_csv(test_url, header=None, sep=',', skiprows=[0])
    
    # assign column names
    columns = ['age', 'workclass', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 
                       'relationship','race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
                       'income-class']
    
    dfTrain.columns, dfTest.columns = columns, columns 
    
    dfTrain["income-class"] = dfTrain["income-class"].str.replace(".","",regex=True)
    dfTest["income-class"] = dfTest["income-class"].str.replace(".","",regex=True)
  
    # Remove question mark
    dfTrain = dfTrain[(dfTrain.values !='?').all(axis=1)]
    dfTest = dfTest[(dfTest.values !='?').all(axis=1)]

    dfTrain = dfTrain.drop(['fnlwgt','education'], axis=1)
    dfTrain = dfTrain.drop_duplicates()
    dfTrain = dfTrain.dropna(how='any', axis=0)
    
    dfTrain['workclass'] = dfTrain['workclass'].str.replace('State-gov', 'Government', regex=True)
    dfTrain['workclass'] = dfTrain['workclass'].str.replace('Federal-gov', 'Government', regex=True)
    dfTrain['workclass'] = dfTrain['workclass'].str.replace('Local-gov', 'Government', regex=True)
    dfTrain['workclass'] = dfTrain['workclass'].str.replace('Self-emp-not-inc', 'Self-Employed', regex=True)
    dfTrain['workclass'] = dfTrain['workclass'].str.replace('Self-emp-inc', 'Self-Employed', regex=True)
    dfTrain['workclass'] = dfTrain['workclass'].str.replace('Private', 'Privately-Employed', regex=True)
    
    dfTrain['occupation'] = dfTrain['occupation'].str.replace('Armed-Forces', 'Protective-serv', regex=True)
    
    dfTrain['marital-status'] = dfTrain['marital-status'].str.replace('Married-AF-spouse', 'Married', regex=True)
    dfTrain['marital-status'] = dfTrain['marital-status'].str.replace('Married-civ-spouse', 'Married', regex=True)
    dfTrain['marital-status'] = dfTrain['marital-status'].str.replace('Married-spouse-absent', 'Married', regex=True)
    dfTrain['marital-status'] = dfTrain['marital-status'].str.replace('Divorced', 'Not-married', regex=True)
    dfTrain['marital-status'] = dfTrain['marital-status'].str.replace('Never-married', 'Not-married', regex=True)
    dfTrain['marital-status'] = dfTrain['marital-status'].str.replace('Separated', 'Not-married', regex=True)
    dfTrain['marital-status'] = dfTrain['marital-status'].str.replace('Widowed', 'Not-married', regex=True)
    
    dfTrain['sex'] = dfTrain['sex'].astype('category').cat.codes
    dfTrain['income-class'] = dfTrain['income-class'].astype('category').cat.codes
    dfTrain['race'] = np.where(dfTrain['race'] == ' White', 1,0)
    
    to_replace = ['workclass', 'education-num', 'marital-status', 'occupation','relationship', 'native-country']
    dfTrain = pd.get_dummies(dfTrain, columns=to_replace, drop_first = False)
    
    dfTrain = dfTrain.drop('native-country_ Holand-Netherlands', axis=1)
    dfTrain = dfTrain.drop(['workclass_ ?', 'native-country_ ?', 'occupation_ ?'], axis=1)
    
    def numericalBinary(dataset, features):
        dataset[features] = np.where(dataset[features] >= dataset[features].mean(), 1,0)

    numericalBinary(dfTrain,['age', 'hours-per-week', 'capital-gain', 'capital-loss'])
 
    
    dfTest = dfTest.drop(['fnlwgt','education'], axis=1)
    dfTest = dfTest.drop_duplicates()
    dfTest = dfTest.dropna(how='any', axis=0)
        
    dfTest['workclass'] = dfTest['workclass'].str.replace('State-gov', 'Government', regex=True)
    dfTest['workclass'] = dfTest['workclass'].str.replace('Federal-gov', 'Government', regex=True)
    dfTest['workclass'] = dfTest['workclass'].str.replace('Local-gov', 'Government', regex=True)
    dfTest['workclass'] = dfTest['workclass'].str.replace('Self-emp-not-inc', 'Self-Employed', regex=True)
    dfTest['workclass'] = dfTest['workclass'].str.replace('Self-emp-inc', 'Self-Employed', regex=True)
    dfTest['workclass'] = dfTest['workclass'].str.replace('Private', 'Privately-Employed', regex=True)
    
    dfTest['occupation'] = dfTest['occupation'].str.replace('Armed-Forces', 'Protective-serv', regex=True)
    
    dfTest['marital-status'] = dfTest['marital-status'].str.replace('Married-AF-spouse', 'Married', regex=True)
    dfTest['marital-status'] = dfTest['marital-status'].str.replace('Married-civ-spouse', 'Married', regex=True)
    dfTest['marital-status'] = dfTest['marital-status'].str.replace('Married-spouse-absent', 'Married', regex=True)
    dfTest['marital-status'] = dfTest['marital-status'].str.replace('Divorced', 'Not-married', regex=True)
    dfTest['marital-status'] = dfTest['marital-status'].str.replace('Never-married', 'Not-married', regex=True)
    dfTest['marital-status'] = dfTest['marital-status'].str.replace('Separated', 'Not-married', regex=True)
    dfTest['marital-status'] = dfTest['marital-status'].str.replace('Widowed', 'Not-married', regex=True)
    
    dfTest['sex'] = dfTest['sex'].astype('category').cat.codes
    dfTest['income-class'] = dfTest['income-class'].astype('category').cat.codes
    dfTest['race'] = np.where(dfTest['race'] == ' White', 1,0)
    
    dfTest = pd.get_dummies(dfTest, columns=to_replace, drop_first = False)

    numericalBinary(dfTest,['age', 'hours-per-week', 'capital-gain', 'capital-loss'])
    
    dfTest = dfTest.drop(['workclass_ ?', 'native-country_ ?', 'occupation_ ?'], axis=1)
    
    data = pd.concat([dfTrain, dfTest], axis=0, ignore_index=False)
    data = data.sample(frac=1, ignore_index=True)
    

    num_train = int(len(data) * .8)
    dfTrain = data.sample(n=num_train, replace=False, axis=0, ignore_index=False)

    dfTest = data.drop(dfTrain.index, axis=0)
    
    dfTrain = dfTrain.dropna(how='any', axis=0)
    dfTest = dfTest.dropna(how='any', axis=0)

    label = 'income-class'
    return dfTrain, dfTest, label

# %%
def sigmoid(z):
    return 1.0 / (1 + np.exp(-z))

# %% [markdown]
# ### Randomized Response

# %%
def get_p(epsilon):
    p = float(E ** epsilon) / float(1 + (E ** epsilon))
    q = 1-p
    
    return p, q

# %% [markdown]
# ### Models

# %%
class LogReg(torch.nn.Module):
    def __init__(self, num_features, scikit_model):
        super(LogReg, self).__init__()
        
        self.fc1 = torch.nn.Linear(num_features, 1, bias=False)
        self.criterion = torch.nn.BCEWithLogitsLoss(reduction='mean')
        
        weights = torch.from_numpy(scikit_model.coef_).type(torch.float32)
        biases = torch.from_numpy(np.array(scikit_model.intercept_)).type(torch.float32)

        with torch.no_grad():
            self.fc1.weight = nn.Parameter(weights)
            self.fc1.bias = nn.Parameter(biases)

    def forward(self, x):
        logits = self.fc1(x)

        return logits

# %% [markdown]
# ### Influence Calculation Functions

# %%
def calc_influence_single(scikit_model, epsilon, train_data, test_data, group_data, device, num_features, criterion):
        
    torch_model = LogReg(num_features, scikit_model)
    torch_model.to(device)
    
    start = time.time()
    est_hess = explicit_hess(torch_model, train_data, device, criterion)
    
    grad_test = grad_z([test_data[0], test_data[1]], torch_model, device, criterion)
 
    s_test_vec = torch.mm(grad_test[0], est_hess.to(device))

    p, q = get_p(epsilon) 
    
    p_01, p_10 = q, q
    
    S_pert = 1 - group_data[1]
    
    y_w_group_pert = pd.concat([group_data[3], S_pert], axis = 0, ignore_index=True)
    y_wo_pert = pd.concat([group_data[3], group_data[1]], axis = 0, ignore_index=True)
    reconstructed_x = pd.concat([group_data[2], group_data[0]], axis = 0, ignore_index=True)
  
    assert len(S_pert) == len(group_data[1])
    grad_z_vec = grad_training([group_data[0], group_data[1]], S_pert, torch_model, device, epsilon)
   
    influence = torch.dot(s_test_vec.flatten(), grad_z_vec[0].flatten()) * (1/len(reconstructed_x))
    end = time.time() - start
    
    return influence.cpu().detach().numpy(), end

# %%
def explicit_hess(model, train_data, device, criterion):

    logits = model(train_data[0])
    loss = criterion(logits.ravel(), train_data[1]) #reduction mean

    grads = grad(loss, model.parameters(), retain_graph=True, create_graph=True)

    hess_params = torch.zeros(len(model.fc1.weight[0]), len(model.fc1.weight[0]))
    
    for i in range(len(model.fc1.weight[0])):
        hess_params_ = grad(grads[0][0][i], model.parameters(), retain_graph=True)[0][0]
        for j, hp in enumerate(hess_params_):
            hess_params[i,j] = hp

    inv_hess = torch.linalg.inv(hess_params)
    return inv_hess

# %%
def grad_z(test_data, model, device, criterion):

    model.eval()

    logits = model(test_data[0])
    loss = criterion(logits.ravel(), test_data[1]) # reduction mean
    
    return grad(loss, model.parameters())

# %%
def grad_training(train_data, y_perts, model, device, epsilon):
    
    criterion = torch.nn.BCEWithLogitsLoss(reduction='sum')
    
    train_data_features = torch.FloatTensor(train_data[0].values).to(device)
    train_data_labels = torch.FloatTensor(train_data[1].values).to(device)
    train_pert_data_labels = torch.FloatTensor(y_perts.values).to(device)
    
    model.eval()
    
    logits = model(train_data_features)

    orig_loss = criterion(logits.ravel(), train_data_labels)
    pert_loss = criterion(logits.ravel(), train_pert_data_labels)
    loss = float(1/(1 + (E ** epsilon)))*(pert_loss - orig_loss)
    
    to_return = grad(loss, model.parameters())
    
        
    return to_return

# %% [markdown]
# ### Main Function

# %%
def Main(dataset, epsilons, ks, num_rounds):

    device = 'cuda:3' if torch.cuda.is_available() else 'cpu'
    criterion = torch.nn.BCEWithLogitsLoss(reduction='mean')
    
    all_orig_loss_e_k = []
    all_est_loss_e_k = []
    all_time = []
    
    for nr in range(num_rounds):
        print(f'\nRound {nr+1}')
        ############
        # Get data #
        ############
        print('\nGetting Data...')
        
        dfTrain, dfTest, label = get_adult()

        feature_set = list(set(dfTrain.columns) - {label})
        num_features = len(feature_set)

        X_train, X_test = dfTrain[feature_set].values, dfTest[feature_set].values
        y_train, y_test = dfTrain[label].values, dfTest[label].values
#        
#         new_train_df = pd.concat([X_train, y_train], axis=1)
  
#         train_sample_num = len(X_train)
    
        x_test_input = torch.FloatTensor(X_test).to(device)
        y_test_input = torch.FloatTensor(y_test).to(device)

        x_train_input = torch.FloatTensor(X_train).to(device)
        y_train_input = torch.FloatTensor(y_train).to(device)
   
        ##############################################
        # Train original model and get original loss #
        ##############################################
        print('Training original model...')
        LR = SGDClassifier(loss='log_loss', penalty='None', eta0=0.01, fit_intercept=False, learning_rate='constant')
        LR.fit(X_train, y_train)
        
        model_to_send = deepcopy(LR)
        
        predictions = LR.predict_proba(X_test)
        label_predictions = [np.argmax(p) for p in predictions]
      
        acc_ori = accuracy_score(y_test, label_predictions)
        test_loss_ori = log_loss(y_test, predictions, eps=1e-15, labels=[0,1])
        
        e_k_act_losses = []
        e_k_est_losses = []
        influence_time = []
                
        ################################################################
        # Perform influence and retraining for all epsilons a k values #
        ################################################################
        print('\nBegining epsilon and k rounds')
        print('-----------------------------')
        for ep in epsilons:
            print(f'\nEpsilon: {ep}')
            
            k_act_losses = []
            k_est_losses = []
            inf_time = []
            
            for k in ks:
                # Influence
                print(f'k: {k:.2f}')
                selected_group_X, selected_group_y, not_selected_group_X, not_selected_group_y = get_data_group(dfTrain, feature_set, label, k)
                loss_diff_approx, tot_time = calc_influence_single(model_to_send, ep, [x_train_input, y_train_input], [x_test_input, y_test_input], [selected_group_X, selected_group_y, not_selected_group_X, not_selected_group_y], device, num_features, criterion)
                print(f'Approx difference: {loss_diff_approx:.5f}')
              
                ###########
                # Retrain #
                ###########
                
                p, q = get_p(ep)
                
                pert_selected_group_y = []
                
                for i, elem in enumerate(selected_group_y.values):
                    rnd = np.random.random()
                    if rnd <= p:
                        pert_selected_group_y.append(elem)
                    else:
                        pert_selected_group_y.append(1 - elem)

                y_w_group_pert = pd.concat([not_selected_group_y, pd.DataFrame(pert_selected_group_y)], axis = 0, ignore_index=True)
                y_wo_pert = pd.concat([not_selected_group_y, selected_group_y], axis = 0, ignore_index=True)
                reconstructed_x = pd.concat([not_selected_group_X, selected_group_X], axis = 0, ignore_index=True)
                
                pert_LR = SGDClassifier(loss='log_loss', penalty='None', eta0=0.01, fit_intercept=False, learning_rate='constant')
                pert_LR.fit(reconstructed_x, y_w_group_pert)
                pert_param = LR.coef_

                pert_predictions = pert_LR.predict_proba(X_test)
                pert_label_predictions = [np.argmax(p) for p in pert_predictions]

                acc_pert = accuracy_score(y_test, pert_label_predictions)
                test_loss_retrain = log_loss(y_test, pert_predictions, eps=1e-15, labels=[0,1])
                
#                 model_pert = LogisticRegression(num_features)
#                 model_pert.load_state_dict(torch.load('initial_config.pth'))
#                 model_pert.to(device)
#                 model_pert = train(model_pert, [torch.FloatTensor(reconstructed_x.values).to(device), torch.FloatTensor(y_w_group_pert.values).to(device)])
#                 test_loss_retrain, acc_retrain = model_pert.loss(model_pert(x_test_input), y_test_input, False)

                 # get true loss diff
                loss_diff_true = test_loss_retrain - test_loss_ori
                print(f'True difference: {loss_diff_true:.5f}')
                k_act_losses.append(loss_diff_true)
                k_est_losses.append(loss_diff_approx)
                inf_time.append(tot_time)
            
            e_k_act_losses.append(k_act_losses)
            e_k_est_losses.append(k_est_losses)
            influence_time.append(inf_time)
            
        all_orig_loss_e_k.append(e_k_act_losses)
        all_est_loss_e_k.append(e_k_est_losses) 
        all_time.append(influence_time)
    
    return all_orig_loss_e_k, all_est_loss_e_k, all_time

# %% [markdown]
# ### Perform Experiment

# %% [markdown]
# #### Constants

# %%
epsilons = np.linspace(.001, 5, 30) #30
k = np.linspace(75, 75, 1) #10
rounds = 10

# %%
all_orig_loss_e_k, all_est_loss_e_k, all_time = Main('adult', epsilons, k, rounds)

with open('all_orig_loss_e_k_adult_full_k.txt', "wb") as file:   #Pickling
    pickle.dump(all_orig_loss_e_k, file)

with open('all_est_loss_e_k_adult_full_k.txt', "wb") as file2:   #Pickling
    pickle.dump(all_est_loss_e_k, file2)
# Out:
# Round 1
#
# Getting Data...
# Training original model...
#
# Begining epsilon and k rounds
# -----------------------------
#
# Epsilon: 0.001
# k: 75.00
# Approx difference: 0.17457
# True difference: 0.24854
#
# Epsilon: 0.17337931034482756
# k: 75.00
# Approx difference: 0.15768
# True difference: 0.18476
#
# Epsilon: 0.3457586206896551
# k: 75.00
# Approx difference: 0.14369
# True difference: 0.14601
#
# Epsilon: 0.5181379310344827
# k: 75.00
# Approx difference: 0.12813
# True difference: 0.14125
#
# Epsilon: 0.6905172413793103
# k: 75.00
# Approx difference: 0.11664
# True difference: 0.14242
#
# Epsilon: 0.8628965517241378
# k: 75.00
# Approx difference: 0.10226
# True difference: 0.10337
#
# Epsilon: 1.0352758620689653
# k: 75.00
# Approx difference: 0.09042
# True difference: 0.10364
#
# Epsilon: 1.207655172413793
# k: 75.00
# Approx difference: 0.07994
# True difference: 0.07966
#
# Epsilon: 1.3800344827586204
# k: 75.00
# Approx difference: 0.07024
# True difference: 0.06117
#
# Epsilon: 1.5524137931034478
# k: 75.00
# Approx difference: 0.06013
# True difference: 0.06323
#
# Epsilon: 1.7247931034482755
# k: 75.00
# Approx difference: 0.05199
# True difference: 0.04033
#
# Epsilon: 1.8971724137931032
# k: 75.00
# Approx difference: 0.04494
# True difference: 0.04873
#
# Epsilon: 2.0695517241379306
# k: 75.00
# Approx difference: 0.03955
# True difference: 0.02459
#
# Epsilon: 2.241931034482758
# k: 75.00
# Approx difference: 0.03374
# True difference: 0.02270
#
# Epsilon: 2.414310344827586
# k: 75.00
# Approx difference: 0.02881
# True difference: 0.01256
#
# Epsilon: 2.5866896551724134
# k: 75.00
# Approx difference: 0.02420
# True difference: 0.01638
#
# Epsilon: 2.759068965517241
# k: 75.00
# Approx difference: 0.02068
# True difference: 0.00942
#
# Epsilon: 2.9314482758620684
# k: 75.00
# Approx difference: 0.01797
# True difference: 0.00590
#
# Epsilon: 3.103827586206896
# k: 75.00
# Approx difference: 0.01478
# True difference: 0.00849
#
# Epsilon: 3.2762068965517237
# k: 75.00
# Approx difference: 0.01256
# True difference: 0.00165
#
# Epsilon: 3.448586206896551
# k: 75.00
# Approx difference: 0.01079
# True difference: 0.00272
#
# Epsilon: 3.6209655172413786
# k: 75.00
# Approx difference: 0.00920
# True difference: 0.00326
#
# Epsilon: 3.7933448275862065
# k: 75.00
# Approx difference: 0.00763
# True difference: 0.00271
#
# Epsilon: 3.965724137931034
# k: 75.00
# Approx difference: 0.00634
# True difference: 0.00100
#
# Epsilon: 4.138103448275862
# k: 75.00
# Approx difference: 0.00544
# True difference: 0.00073
#
# Epsilon: 4.310482758620689
# k: 75.00
# Approx difference: 0.00468
# True difference: 0.00257
#
# Epsilon: 4.482862068965517
# k: 75.00
# Approx difference: 0.00395
# True difference: 0.00279
#
# Epsilon: 4.655241379310344
# k: 75.00
# Approx difference: 0.00330
# True difference: 0.00279
#
# Epsilon: 4.8276206896551725
# k: 75.00
# Approx difference: 0.00276
# True difference: 0.00016
#
# Epsilon: 5.0
# k: 75.00
# Approx difference: 0.00238
# True difference: -0.00035
#
# Round 2
#
# Getting Data...
# Training original model...
#
# Begining epsilon and k rounds
# -----------------------------
#
# Epsilon: 0.001
# k: 75.00
# Approx difference: -0.00356
# True difference: 0.23620
#
# Epsilon: 0.17337931034482756
# k: 75.00
# Approx difference: -0.00294
# True difference: 0.20174
#
# Epsilon: 0.3457586206896551
# k: 75.00
# Approx difference: -0.00306
# True difference: 0.22032
#
# Epsilon: 0.5181379310344827
# k: 75.00
# Approx difference: -0.00206
# True difference: 0.13768
#
# Epsilon: 0.6905172413793103
# k: 75.00
# Approx difference: -0.00299
# True difference: 0.11528
#
# Epsilon: 0.8628965517241378
# k: 75.00
# Approx difference: -0.00228
# True difference: 0.11282
#
# Epsilon: 1.0352758620689653
# k: 75.00
# Approx difference: -0.00157
# True difference: 0.11315
#
# Epsilon: 1.207655172413793
# k: 75.00
# Approx difference: -0.00163
# True difference: 0.09000
#
# Epsilon: 1.3800344827586204
# k: 75.00
# Approx difference: -0.00110
# True difference: 0.07906
#
# Epsilon: 1.5524137931034478
# k: 75.00
# Approx difference: -0.00131
# True difference: 0.04587
#
# Epsilon: 1.7247931034482755
# k: 75.00
# Approx difference: -0.00100
# True difference: 0.04561
#
# Epsilon: 1.8971724137931032
# k: 75.00
# Approx difference: -0.00076
# True difference: 0.03266
#
# Epsilon: 2.0695517241379306
# k: 75.00
# Approx difference: -0.00086
# True difference: 0.02638
#
# Epsilon: 2.241931034482758
# k: 75.00
# Approx difference: -0.00070
# True difference: 0.03878
#
# Epsilon: 2.414310344827586
# k: 75.00
# Approx difference: -0.00048
# True difference: 0.02188
#
# Epsilon: 2.5866896551724134
# k: 75.00
# Approx difference: -0.00056
# True difference: 0.01164
#
# Epsilon: 2.759068965517241
# k: 75.00
# Approx difference: -0.00043
# True difference: 0.01187
#
# Epsilon: 2.9314482758620684
# k: 75.00
# Approx difference: -0.00033
# True difference: 0.01155
#
# Epsilon: 3.103827586206896
# k: 75.00
# Approx difference: -0.00030
# True difference: 0.00456
#
# Epsilon: 3.2762068965517237
# k: 75.00
# Approx difference: -0.00029
# True difference: 0.00459
#
# Epsilon: 3.448586206896551
# k: 75.00
# Approx difference: -0.00021
# True difference: 0.00321
#
# Epsilon: 3.6209655172413786
# k: 75.00
# Approx difference: -0.00020
# True difference: 0.00079
#
# Epsilon: 3.7933448275862065
# k: 75.00
# Approx difference: -0.00013
# True difference: 0.00313
#
# Epsilon: 3.965724137931034
# k: 75.00
# Approx difference: -0.00012
# True difference: -0.00074
#
# Epsilon: 4.138103448275862
# k: 75.00
# Approx difference: -0.00009
# True difference: -0.00047
#
# Epsilon: 4.310482758620689
# k: 75.00
# Approx difference: -0.00008
# True difference: 0.00001
#
# Epsilon: 4.482862068965517
# k: 75.00
# Approx difference: -0.00007
# True difference: 0.00078
#
# Epsilon: 4.655241379310344
# k: 75.00
# Approx difference: -0.00007
# True difference: -0.00145
#
# Epsilon: 4.8276206896551725
# k: 75.00
# Approx difference: -0.00006
# True difference: -0.00090
#
# Epsilon: 5.0
# k: 75.00
# Approx difference: -0.00004
# True difference: -0.00245
#
# Round 3
#
# Getting Data...
# Training original model...
#
# Begining epsilon and k rounds
# -----------------------------
#
# Epsilon: 0.001
# k: 75.00
# Approx difference: 0.03743
# True difference: 0.23117
#
# Epsilon: 0.17337931034482756
# k: 75.00
# Approx difference: 0.03498
# True difference: 0.22077
#
# Epsilon: 0.3457586206896551
# k: 75.00
# Approx difference: 0.03153
# True difference: 0.18493
#
# Epsilon: 0.5181379310344827
# k: 75.00
# Approx difference: 0.02868
# True difference: 0.15002
#
# Epsilon: 0.6905172413793103
# k: 75.00
# Approx difference: 0.02457
# True difference: 0.15038
#
# Epsilon: 0.8628965517241378
# k: 75.00
# Approx difference: 0.02263
# True difference: 0.09755
#
# Epsilon: 1.0352758620689653
# k: 75.00
# Approx difference: 0.01935
# True difference: 0.11051
#
# Epsilon: 1.207655172413793
# k: 75.00
# Approx difference: 0.01720
# True difference: 0.06698
#
# Epsilon: 1.3800344827586204
# k: 75.00
# Approx difference: 0.01509
# True difference: 0.07619
#
# Epsilon: 1.5524137931034478
# k: 75.00
# Approx difference: 0.01327
# True difference: 0.05389
#
# Epsilon: 1.7247931034482755
# k: 75.00
# Approx difference: 0.01135
# True difference: 0.03824
#
# Epsilon: 1.8971724137931032
# k: 75.00
# Approx difference: 0.00989
# True difference: 0.02787
#
# Epsilon: 2.0695517241379306
# k: 75.00
# Approx difference: 0.00832
# True difference: 0.02530
#
# Epsilon: 2.241931034482758
# k: 75.00
# Approx difference: 0.00716
# True difference: 0.02208
#
# Epsilon: 2.414310344827586
# k: 75.00
# Approx difference: 0.00620
# True difference: 0.02060
#
# Epsilon: 2.5866896551724134
# k: 75.00
# Approx difference: 0.00517
# True difference: 0.01052
#
# Epsilon: 2.759068965517241
# k: 75.00
# Approx difference: 0.00448
# True difference: 0.01101
#
# Epsilon: 2.9314482758620684
# k: 75.00
# Approx difference: 0.00386
# True difference: 0.00716
#
# Epsilon: 3.103827586206896
# k: 75.00
# Approx difference: 0.00319
# True difference: 0.00712
#
# Epsilon: 3.2762068965517237
# k: 75.00
# Approx difference: 0.00278
# True difference: 0.00253
#
# Epsilon: 3.448586206896551
# k: 75.00
# Approx difference: 0.00236
# True difference: 0.00360
#
# Epsilon: 3.6209655172413786
# k: 75.00
# Approx difference: 0.00199
# True difference: 0.00080
#
# Epsilon: 3.7933448275862065
# k: 75.00
# Approx difference: 0.00165
# True difference: 0.00521
#
# Epsilon: 3.965724137931034
# k: 75.00
# Approx difference: 0.00143
# True difference: 0.00345
#
# Epsilon: 4.138103448275862
# k: 75.00
# Approx difference: 0.00120
# True difference: 0.00148
#
# Epsilon: 4.310482758620689
# k: 75.00
# Approx difference: 0.00097
# True difference: 0.00125
#
# Epsilon: 4.482862068965517
# k: 75.00
# Approx difference: 0.00088
# True difference: 0.00074
#
# Epsilon: 4.655241379310344
# k: 75.00
# Approx difference: 0.00072
# True difference: 0.00054
#
# Epsilon: 4.8276206896551725
# k: 75.00
# Approx difference: 0.00060
# True difference: 0.00042
#
# Epsilon: 5.0
# k: 75.00
# Approx difference: 0.00050
# True difference: 0.00007
#
# Round 4
#
# Getting Data...
# Training original model...
#
# Begining epsilon and k rounds
# -----------------------------
#
# Epsilon: 0.001
# k: 75.00
# Approx difference: -0.00226
# True difference: 0.22887
#
# Epsilon: 0.17337931034482756
# k: 75.00
# Approx difference: -0.00181
# True difference: 0.18968
#
# Epsilon: 0.3457586206896551
# k: 75.00
# Approx difference: -0.00261
# True difference: 0.14186
#
# Epsilon: 0.5181379310344827
# k: 75.00
# Approx difference: -0.00190
# True difference: 0.15153
#
# Epsilon: 0.6905172413793103
# k: 75.00
# Approx difference: -0.00149
# True difference: 0.13807
#
# Epsilon: 0.8628965517241378
# k: 75.00
# Approx difference: -0.00180
# True difference: 0.09783
#
# Epsilon: 1.0352758620689653
# k: 75.00
# Approx difference: -0.00104
# True difference: 0.07811
#
# Epsilon: 1.207655172413793
# k: 75.00
# Approx difference: -0.00134
# True difference: 0.07821
#
# Epsilon: 1.3800344827586204
# k: 75.00
# Approx difference: -0.00090
# True difference: 0.08275
#
# Epsilon: 1.5524137931034478
# k: 75.00
# Approx difference: -0.00084
# True difference: 0.06518
#
# Epsilon: 1.7247931034482755
# k: 75.00
# Approx difference: -0.00076
# True difference: 0.04197
#
# Epsilon: 1.8971724137931032
# k: 75.00
# Approx difference: -0.00081
# True difference: 0.03065
#
# Epsilon: 2.0695517241379306
# k: 75.00
# Approx difference: -0.00045
# True difference: 0.02723
#
# Epsilon: 2.241931034482758
# k: 75.00
# Approx difference: -0.00052
# True difference: 0.03196
#
# Epsilon: 2.414310344827586
# k: 75.00
# Approx difference: -0.00034
# True difference: 0.02267
#
# Epsilon: 2.5866896551724134
# k: 75.00
# Approx difference: -0.00018
# True difference: 0.01049
#
# Epsilon: 2.759068965517241
# k: 75.00
# Approx difference: -0.00034
# True difference: 0.00866
#
# Epsilon: 2.9314482758620684
# k: 75.00
# Approx difference: -0.00038
# True difference: 0.00914
#
# Epsilon: 3.103827586206896
# k: 75.00
# Approx difference: -0.00027
# True difference: 0.01131
#
# Epsilon: 3.2762068965517237
# k: 75.00
# Approx difference: -0.00015
# True difference: 0.00761
#
# Epsilon: 3.448586206896551
# k: 75.00
# Approx difference: -0.00014
# True difference: 0.00396
#
# Epsilon: 3.6209655172413786
# k: 75.00
# Approx difference: -0.00013
# True difference: 0.00077
#
# Epsilon: 3.7933448275862065
# k: 75.00
# Approx difference: -0.00010
# True difference: -0.00002
#
# Epsilon: 3.965724137931034
# k: 75.00
# Approx difference: -0.00010
# True difference: 0.00186
#
# Epsilon: 4.138103448275862
# k: 75.00
# Approx difference: -0.00007
# True difference: -0.00078
#
# Epsilon: 4.310482758620689
# k: 75.00
# Approx difference: -0.00006
# True difference: 0.00070
#
# Epsilon: 4.482862068965517
# k: 75.00
# Approx difference: -0.00008
# True difference: 0.00375
#
# Epsilon: 4.655241379310344
# k: 75.00
# Approx difference: -0.00005
# True difference: 0.00243
#
# Epsilon: 4.8276206896551725
# k: 75.00
# Approx difference: -0.00004
# True difference: 0.00665
#
# Epsilon: 5.0
# k: 75.00
# Approx difference: -0.00003
# True difference: 0.00050
#
# Round 5
#
# Getting Data...
# Training original model...
#
# Begining epsilon and k rounds
# -----------------------------
#
# Epsilon: 0.001
# k: 75.00
# Approx difference: -0.08064
# True difference: 0.20563
#
# Epsilon: 0.17337931034482756
# k: 75.00
# Approx difference: -0.07374
# True difference: 0.19617
#
# Epsilon: 0.3457586206896551
# k: 75.00
# Approx difference: -0.06816
# True difference: 0.16287
#
# Epsilon: 0.5181379310344827
# k: 75.00
# Approx difference: -0.06029
# True difference: 0.14021
#
# Epsilon: 0.6905172413793103
# k: 75.00
# Approx difference: -0.05516
# True difference: 0.10628
#
# Epsilon: 0.8628965517241378
# k: 75.00
# Approx difference: -0.04806
# True difference: 0.09494
#
# Epsilon: 1.0352758620689653
# k: 75.00
# Approx difference: -0.04288
# True difference: 0.11455
#
# Epsilon: 1.207655172413793
# k: 75.00
# Approx difference: -0.03771
# True difference: 0.08174
#
# Epsilon: 1.3800344827586204
# k: 75.00
# Approx difference: -0.03262
# True difference: 0.05818
#
# Epsilon: 1.5524137931034478
# k: 75.00
# Approx difference: -0.02873
# True difference: 0.04139
#
# Epsilon: 1.7247931034482755
# k: 75.00
# Approx difference: -0.02464
# True difference: 0.03945
#
# Epsilon: 1.8971724137931032
# k: 75.00
# Approx difference: -0.02138
# True difference: 0.02174
#
# Epsilon: 2.0695517241379306
# k: 75.00
# Approx difference: -0.01824
# True difference: 0.02075
#
# Epsilon: 2.241931034482758
# k: 75.00
# Approx difference: -0.01568
# True difference: 0.01203
#
# Epsilon: 2.414310344827586
# k: 75.00
# Approx difference: -0.01342
# True difference: 0.01394
#
# Epsilon: 2.5866896551724134
# k: 75.00
# Approx difference: -0.01160
# True difference: 0.00511
#
# Epsilon: 2.759068965517241
# k: 75.00
# Approx difference: -0.00975
# True difference: 0.00242
#
# Epsilon: 2.9314482758620684
# k: 75.00
# Approx difference: -0.00825
# True difference: -0.00227
#
# Epsilon: 3.103827586206896
# k: 75.00
# Approx difference: -0.00698
# True difference: -0.00134
#
# Epsilon: 3.2762068965517237
# k: 75.00
# Approx difference: -0.00591
# True difference: -0.00256
#
# Epsilon: 3.448586206896551
# k: 75.00
# Approx difference: -0.00510
# True difference: -0.00366
#
# Epsilon: 3.6209655172413786
# k: 75.00
# Approx difference: -0.00422
# True difference: -0.00613
#
# Epsilon: 3.7933448275862065
# k: 75.00
# Approx difference: -0.00357
# True difference: -0.00561
#
# Epsilon: 3.965724137931034
# k: 75.00
# Approx difference: -0.00305
# True difference: -0.00680
#
# Epsilon: 4.138103448275862
# k: 75.00
# Approx difference: -0.00252
# True difference: -0.00142
#
# Epsilon: 4.310482758620689
# k: 75.00
# Approx difference: -0.00219
# True difference: 0.00430
#
# Epsilon: 4.482862068965517
# k: 75.00
# Approx difference: -0.00182
# True difference: -0.00748
#
# Epsilon: 4.655241379310344
# k: 75.00
# Approx difference: -0.00153
# True difference: -0.00748
#
# Epsilon: 4.8276206896551725
# k: 75.00
# Approx difference: -0.00128
# True difference: -0.00813
#
# Epsilon: 5.0
# k: 75.00
# Approx difference: -0.00109
# True difference: -0.00673
#
# Round 6
#
# Getting Data...
# Training original model...
#
# Begining epsilon and k rounds
# -----------------------------
#
# Epsilon: 0.001
# k: 75.00
# Approx difference: 0.00059
# True difference: 0.19738
#
# Epsilon: 0.17337931034482756
# k: 75.00
# Approx difference: 0.00192
# True difference: 0.17328
#
# Epsilon: 0.3457586206896551
# k: 75.00
# Approx difference: 0.00195
# True difference: 0.17845
#
# Epsilon: 0.5181379310344827
# k: 75.00
# Approx difference: 0.00154
# True difference: 0.18779
#
# Epsilon: 0.6905172413793103
# k: 75.00
# Approx difference: 0.00120
# True difference: 0.13052
#
# Epsilon: 0.8628965517241378
# k: 75.00
# Approx difference: 0.00111
# True difference: 0.11930
#
# Epsilon: 1.0352758620689653
# k: 75.00
# Approx difference: 0.00072
# True difference: 0.10294
#
# Epsilon: 1.207655172413793
# k: 75.00
# Approx difference: 0.00042
# True difference: 0.07295
#
# Epsilon: 1.3800344827586204
# k: 75.00
# Approx difference: 0.00063
# True difference: 0.06701
#
# Epsilon: 1.5524137931034478
# k: 75.00
# Approx difference: 0.00059
# True difference: 0.05780
#
# Epsilon: 1.7247931034482755
# k: 75.00
# Approx difference: 0.00042
# True difference: 0.04187
#
# Epsilon: 1.8971724137931032
# k: 75.00
# Approx difference: 0.00055
# True difference: 0.05039
#
# Epsilon: 2.0695517241379306
# k: 75.00
# Approx difference: 0.00024
# True difference: 0.01872
#
# Epsilon: 2.241931034482758
# k: 75.00
# Approx difference: 0.00015
# True difference: 0.02268
#
# Epsilon: 2.414310344827586
# k: 75.00
# Approx difference: 0.00038
# True difference: 0.01526
#
# Epsilon: 2.5866896551724134
# k: 75.00
# Approx difference: 0.00020
# True difference: 0.01381
#
# Epsilon: 2.759068965517241
# k: 75.00
# Approx difference: 0.00020
# True difference: 0.01276
#
# Epsilon: 2.9314482758620684
# k: 75.00
# Approx difference: 0.00013
# True difference: 0.02212
#
# Epsilon: 3.103827586206896
# k: 75.00
# Approx difference: 0.00011
# True difference: 0.00338
#
# Epsilon: 3.2762068965517237
# k: 75.00
# Approx difference: 0.00019
# True difference: 0.00347
#
# Epsilon: 3.448586206896551
# k: 75.00
# Approx difference: 0.00008
# True difference: 0.00349
#
# Epsilon: 3.6209655172413786
# k: 75.00
# Approx difference: 0.00004
# True difference: 0.00144
#
# Epsilon: 3.7933448275862065
# k: 75.00
# Approx difference: 0.00007
# True difference: 0.00126
#
# Epsilon: 3.965724137931034
# k: 75.00
# Approx difference: 0.00009
# True difference: -0.00052
#
# Epsilon: 4.138103448275862
# k: 75.00
# Approx difference: 0.00005
# True difference: 0.00015
#
# Epsilon: 4.310482758620689
# k: 75.00
# Approx difference: 0.00006
# True difference: 0.00060
#
# Epsilon: 4.482862068965517
# k: 75.00
# Approx difference: 0.00004
# True difference: 0.00230
#
# Epsilon: 4.655241379310344
# k: 75.00
# Approx difference: 0.00003
# True difference: -0.00052
#
# Epsilon: 4.8276206896551725
# k: 75.00
# Approx difference: 0.00003
# True difference: 0.00031
#
# Epsilon: 5.0
# k: 75.00
# Approx difference: 0.00002
# True difference: 0.00040
#
# Round 7
#
# Getting Data...
# Training original model...
#
# Begining epsilon and k rounds
# -----------------------------
#
# Epsilon: 0.001
# k: 75.00
# Approx difference: 0.15418
# True difference: 0.21812
#
# Epsilon: 0.17337931034482756
# k: 75.00
# Approx difference: 0.14083
# True difference: 0.19267
#
# Epsilon: 0.3457586206896551
# k: 75.00
# Approx difference: 0.12747
# True difference: 0.15562
#
# Epsilon: 0.5181379310344827
# k: 75.00
# Approx difference: 0.11449
# True difference: 0.16929
#
# Epsilon: 0.6905172413793103
# k: 75.00
# Approx difference: 0.10374
# True difference: 0.12161
#
# Epsilon: 0.8628965517241378
# k: 75.00
# Approx difference: 0.09182
# True difference: 0.08807
#
# Epsilon: 1.0352758620689653
# k: 75.00
# Approx difference: 0.08068
# True difference: 0.09272
#
# Epsilon: 1.207655172413793
# k: 75.00
# Approx difference: 0.06954
# True difference: 0.06337
#
# Epsilon: 1.3800344827586204
# k: 75.00
# Approx difference: 0.06129
# True difference: 0.05811
#
# Epsilon: 1.5524137931034478
# k: 75.00
# Approx difference: 0.05402
# True difference: 0.04682
#
# Epsilon: 1.7247931034482755
# k: 75.00
# Approx difference: 0.04638
# True difference: 0.05399
#
# Epsilon: 1.8971724137931032
# k: 75.00
# Approx difference: 0.04019
# True difference: 0.03596
#
# Epsilon: 2.0695517241379306
# k: 75.00
# Approx difference: 0.03397
# True difference: 0.02831
#
# Epsilon: 2.241931034482758
# k: 75.00
# Approx difference: 0.02970
# True difference: 0.01671
#
# Epsilon: 2.414310344827586
# k: 75.00
# Approx difference: 0.02496
# True difference: 0.01760
#
# Epsilon: 2.5866896551724134
# k: 75.00
# Approx difference: 0.02167
# True difference: 0.01403
#
# Epsilon: 2.759068965517241
# k: 75.00
# Approx difference: 0.01842
# True difference: 0.00898
#
# Epsilon: 2.9314482758620684
# k: 75.00
# Approx difference: 0.01566
# True difference: 0.00678
#
# Epsilon: 3.103827586206896
# k: 75.00
# Approx difference: 0.01328
# True difference: 0.00460
#
# Epsilon: 3.2762068965517237
# k: 75.00
# Approx difference: 0.01118
# True difference: 0.00634
#
# Epsilon: 3.448586206896551
# k: 75.00
# Approx difference: 0.00951
# True difference: 0.00424
#
# Epsilon: 3.6209655172413786
# k: 75.00
# Approx difference: 0.00810
# True difference: 0.00631
#
# Epsilon: 3.7933448275862065
# k: 75.00
# Approx difference: 0.00675
# True difference: 0.00237
#
# Epsilon: 3.965724137931034
# k: 75.00
# Approx difference: 0.00577
# True difference: 0.00263
#
# Epsilon: 4.138103448275862
# k: 75.00
# Approx difference: 0.00485
# True difference: 0.00256
#
# Epsilon: 4.310482758620689
# k: 75.00
# Approx difference: 0.00410
# True difference: 0.00250
#
# Epsilon: 4.482862068965517
# k: 75.00
# Approx difference: 0.00345
# True difference: 0.00270
#
# Epsilon: 4.655241379310344
# k: 75.00
# Approx difference: 0.00290
# True difference: -0.00017
#
# Epsilon: 4.8276206896551725
# k: 75.00
# Approx difference: 0.00243
# True difference: 0.00249
#
# Epsilon: 5.0
# k: 75.00
# Approx difference: 0.00204
# True difference: 0.00065
#
# Round 8
#
# Getting Data...
# Training original model...
#
# Begining epsilon and k rounds
# -----------------------------
#
# Epsilon: 0.001
# k: 75.00
# Approx difference: 0.05518
# True difference: 0.24050
#
# Epsilon: 0.17337931034482756
# k: 75.00
# Approx difference: 0.05013
# True difference: 0.18871
#
# Epsilon: 0.3457586206896551
# k: 75.00
# Approx difference: 0.04577
# True difference: 0.18779
#
# Epsilon: 0.5181379310344827
# k: 75.00
# Approx difference: 0.04151
# True difference: 0.14471
#
# Epsilon: 0.6905172413793103
# k: 75.00
# Approx difference: 0.03726
# True difference: 0.15084
#
# Epsilon: 0.8628965517241378
# k: 75.00
# Approx difference: 0.03253
# True difference: 0.11613
#
# Epsilon: 1.0352758620689653
# k: 75.00
# Approx difference: 0.02931
# True difference: 0.09075
#
# Epsilon: 1.207655172413793
# k: 75.00
# Approx difference: 0.02594
# True difference: 0.08738
#
# Epsilon: 1.3800344827586204
# k: 75.00
# Approx difference: 0.02190
# True difference: 0.09506
#
# Epsilon: 1.5524137931034478
# k: 75.00
# Approx difference: 0.01906
# True difference: 0.07219
#
# Epsilon: 1.7247931034482755
# k: 75.00
# Approx difference: 0.01688
# True difference: 0.06257
#
# Epsilon: 1.8971724137931032
# k: 75.00
# Approx difference: 0.01466
# True difference: 0.03170
#
# Epsilon: 2.0695517241379306
# k: 75.00
# Approx difference: 0.01264
# True difference: 0.03691
#
# Epsilon: 2.241931034482758
# k: 75.00
# Approx difference: 0.01032
# True difference: 0.03025
#
# Epsilon: 2.414310344827586
# k: 75.00
# Approx difference: 0.00897
# True difference: 0.01506
#
# Epsilon: 2.5866896551724134
# k: 75.00
# Approx difference: 0.00781
# True difference: 0.01512
#
# Epsilon: 2.759068965517241
# k: 75.00
# Approx difference: 0.00674
# True difference: 0.00676
#
# Epsilon: 2.9314482758620684
# k: 75.00
# Approx difference: 0.00550
# True difference: 0.00988
#
# Epsilon: 3.103827586206896
# k: 75.00
# Approx difference: 0.00481
# True difference: 0.00472
#
# Epsilon: 3.2762068965517237
# k: 75.00
# Approx difference: 0.00398
# True difference: 0.00453
#
# Epsilon: 3.448586206896551
# k: 75.00
# Approx difference: 0.00341
# True difference: 0.00301
#
# Epsilon: 3.6209655172413786
# k: 75.00
# Approx difference: 0.00288
# True difference: 0.00300
#
# Epsilon: 3.7933448275862065
# k: 75.00
# Approx difference: 0.00241
# True difference: 0.00142
#
# Epsilon: 3.965724137931034
# k: 75.00
# Approx difference: 0.00205
# True difference: 0.00331
#
# Epsilon: 4.138103448275862
# k: 75.00
# Approx difference: 0.00173
# True difference: -0.00045
#
# Epsilon: 4.310482758620689
# k: 75.00
# Approx difference: 0.00149
# True difference: -0.00104
#
# Epsilon: 4.482862068965517
# k: 75.00
# Approx difference: 0.00126
# True difference: -0.00217
#
# Epsilon: 4.655241379310344
# k: 75.00
# Approx difference: 0.00104
# True difference: -0.00259
#
# Epsilon: 4.8276206896551725
# k: 75.00
# Approx difference: 0.00089
# True difference: 0.00110
#
# Epsilon: 5.0
# k: 75.00
# Approx difference: 0.00074
# True difference: -0.00396
#
# Round 9
#
# Getting Data...
# Training original model...
#
# Begining epsilon and k rounds
# -----------------------------
#
# Epsilon: 0.001
# k: 75.00
# Approx difference: 0.01976
# True difference: 0.24581
#
# Epsilon: 0.17337931034482756
# k: 75.00
# Approx difference: 0.01757
# True difference: 0.21370
#
# Epsilon: 0.3457586206896551
# k: 75.00
# Approx difference: 0.01621
# True difference: 0.17713
#
# Epsilon: 0.5181379310344827
# k: 75.00
# Approx difference: 0.01449
# True difference: 0.12449
#
# Epsilon: 0.6905172413793103
# k: 75.00
# Approx difference: 0.01278
# True difference: 0.14565
#
# Epsilon: 0.8628965517241378
# k: 75.00
# Approx difference: 0.01201
# True difference: 0.12622
#
# Epsilon: 1.0352758620689653
# k: 75.00
# Approx difference: 0.01039
# True difference: 0.11713
#
# Epsilon: 1.207655172413793
# k: 75.00
# Approx difference: 0.00920
# True difference: 0.10342
#
# Epsilon: 1.3800344827586204
# k: 75.00
# Approx difference: 0.00783
# True difference: 0.05854
#
# Epsilon: 1.5524137931034478
# k: 75.00
# Approx difference: 0.00650
# True difference: 0.07943
#
# Epsilon: 1.7247931034482755
# k: 75.00
# Approx difference: 0.00607
# True difference: 0.05471
#
# Epsilon: 1.8971724137931032
# k: 75.00
# Approx difference: 0.00523
# True difference: 0.02683
#
# Epsilon: 2.0695517241379306
# k: 75.00
# Approx difference: 0.00434
# True difference: 0.02564
#
# Epsilon: 2.241931034482758
# k: 75.00
# Approx difference: 0.00383
# True difference: 0.02486
#
# Epsilon: 2.414310344827586
# k: 75.00
# Approx difference: 0.00340
# True difference: 0.01408
#
# Epsilon: 2.5866896551724134
# k: 75.00
# Approx difference: 0.00278
# True difference: 0.01149
#
# Epsilon: 2.759068965517241
# k: 75.00
# Approx difference: 0.00243
# True difference: 0.01197
#
# Epsilon: 2.9314482758620684
# k: 75.00
# Approx difference: 0.00202
# True difference: 0.01083
#
# Epsilon: 3.103827586206896
# k: 75.00
# Approx difference: 0.00169
# True difference: 0.00613
#
# Epsilon: 3.2762068965517237
# k: 75.00
# Approx difference: 0.00143
# True difference: 0.00326
#
# Epsilon: 3.448586206896551
# k: 75.00
# Approx difference: 0.00124
# True difference: 0.00413
#
# Epsilon: 3.6209655172413786
# k: 75.00
# Approx difference: 0.00101
# True difference: 0.00418
#
# Epsilon: 3.7933448275862065
# k: 75.00
# Approx difference: 0.00088
# True difference: 0.00723
#
# Epsilon: 3.965724137931034
# k: 75.00
# Approx difference: 0.00069
# True difference: 0.00200
#
# Epsilon: 4.138103448275862
# k: 75.00
# Approx difference: 0.00062
# True difference: 0.00027
#
# Epsilon: 4.310482758620689
# k: 75.00
# Approx difference: 0.00051
# True difference: 0.00061
#
# Epsilon: 4.482862068965517
# k: 75.00
# Approx difference: 0.00045
# True difference: 0.00507
#
# Epsilon: 4.655241379310344
# k: 75.00
# Approx difference: 0.00037
# True difference: 0.00003
#
# Epsilon: 4.8276206896551725
# k: 75.00
# Approx difference: 0.00031
# True difference: 0.00941
#
# Epsilon: 5.0
# k: 75.00
# Approx difference: 0.00026
# True difference: -0.00041
#
# Round 10
#
# Getting Data...
# Training original model...
#
# Begining epsilon and k rounds
# -----------------------------
#
# Epsilon: 0.001
# k: 75.00
# Approx difference: -0.23044
# True difference: 0.23670
#
# Epsilon: 0.17337931034482756
# k: 75.00
# Approx difference: -0.21033
# True difference: 0.17675
#
# Epsilon: 0.3457586206896551
# k: 75.00
# Approx difference: -0.19070
# True difference: 0.21588
#
# Epsilon: 0.5181379310344827
# k: 75.00
# Approx difference: -0.17310
# True difference: 0.14815
#
# Epsilon: 0.6905172413793103
# k: 75.00
# Approx difference: -0.15505
# True difference: 0.13058
#
# Epsilon: 0.8628965517241378
# k: 75.00
# Approx difference: -0.13750
# True difference: 0.13399
#
# Epsilon: 1.0352758620689653
# k: 75.00
# Approx difference: -0.12055
# True difference: 0.07815
#
# Epsilon: 1.207655172413793
# k: 75.00
# Approx difference: -0.10685
# True difference: 0.11857
#
# Epsilon: 1.3800344827586204
# k: 75.00
# Approx difference: -0.09389
# True difference: 0.07531
#
# Epsilon: 1.5524137931034478
# k: 75.00
# Approx difference: -0.08110
# True difference: 0.04994
#
# Epsilon: 1.7247931034482755
# k: 75.00
# Approx difference: -0.06949
# True difference: 0.04825
#
# Epsilon: 1.8971724137931032
# k: 75.00
# Approx difference: -0.06063
# True difference: 0.03510
#
# Epsilon: 2.0695517241379306
# k: 75.00
# Approx difference: -0.05142
# True difference: 0.03668
#
# Epsilon: 2.241931034482758
# k: 75.00
# Approx difference: -0.04405
# True difference: 0.02028
#
# Epsilon: 2.414310344827586
# k: 75.00
# Approx difference: -0.03805
# True difference: 0.01834
#
# Epsilon: 2.5866896551724134
# k: 75.00
# Approx difference: -0.03215
# True difference: 0.01472
#
# Epsilon: 2.759068965517241
# k: 75.00
# Approx difference: -0.02776
# True difference: 0.01516
#
# Epsilon: 2.9314482758620684
# k: 75.00
# Approx difference: -0.02339
# True difference: 0.01510
#
# Epsilon: 3.103827586206896
# k: 75.00
# Approx difference: -0.02004
# True difference: 0.00732
#
# Epsilon: 3.2762068965517237
# k: 75.00
# Approx difference: -0.01676
# True difference: 0.00714
#
# Epsilon: 3.448586206896551
# k: 75.00
# Approx difference: -0.01426
# True difference: 0.00372
#
# Epsilon: 3.6209655172413786
# k: 75.00
# Approx difference: -0.01205
# True difference: 0.00589
#
# Epsilon: 3.7933448275862065
# k: 75.00
# Approx difference: -0.01023
# True difference: 0.00238
#
# Epsilon: 3.965724137931034
# k: 75.00
# Approx difference: -0.00865
# True difference: 0.00344
#
# Epsilon: 4.138103448275862
# k: 75.00
# Approx difference: -0.00731
# True difference: 0.00430
#
# Epsilon: 4.310482758620689
# k: 75.00
# Approx difference: -0.00610
# True difference: 0.00087
#
# Epsilon: 4.482862068965517
# k: 75.00
# Approx difference: -0.00522
# True difference: 0.00044
#
# Epsilon: 4.655241379310344
# k: 75.00
# Approx difference: -0.00432
# True difference: 0.00039
#
# Epsilon: 4.8276206896551725
# k: 75.00
# Approx difference: -0.00367
# True difference: 0.00119
#
# Epsilon: 5.0
# k: 75.00
# Approx difference: -0.00306
# True difference: 0.00075

# %%
with open('all_orig_loss_e_k_adult_full_k.txt', 'rb') as f:
    all_orig_loss_e_k = pickle.load(f)
    
with open('all_est_loss_e_k_adult_full_k.txt', 'rb') as f:
    all_est_loss_e_k = pickle.load(f)

# %%
print(len(all_orig_loss_e_k[0]))
# Out:
# 30

# %%
# [actual, estimate]

sum_orig_loss_e_k = [[0 for _ in range(len(k))] for _ in range(len(epsilons))]
sum_est_loss_e_k = [[0 for _ in range(len(k))] for _ in range(len(epsilons))]
sum_time = [[0 for _ in range(len(k))] for _ in range(len(epsilons))]

avg_orig_loss = []
avg_est_loss = []
avg_time = []

for round_ in range(len(all_orig_loss_e_k)):
    for e in range(len(epsilons)):
        for k_ in range(len(k)):
            sum_orig_loss_e_k[e][k_] = sum_orig_loss_e_k[e][k_] + all_orig_loss_e_k[round_][e][k_]
            sum_est_loss_e_k[e][k_] = sum_est_loss_e_k[e][k_] + all_est_loss_e_k[round_][e][k_]
            

for e in range(len(epsilons)):
    avg_orig_loss.append([ elem / len(all_orig_loss_e_k) for elem in sum_orig_loss_e_k[e]])
    avg_est_loss.append([elem/ len(all_orig_loss_e_k) for elem in sum_est_loss_e_k[e]])

k_e_orig = [[] for _ in range(len(k))]
k_e_est = [[] for _ in range(len(k))]

for e in range(len(epsilons)):
    for k_ in range(len(k)):
        k_e_orig[k_].append(avg_orig_loss[e][k_])
        k_e_est[k_].append(avg_est_loss[e][k_])

# %%
for i in range(len(k_e_orig)):
    visualize_result(k_e_orig[i], k_e_est[i], epsilons, k[i])
# Out:
# MAE = 0.0468
# P = 0.991
